# %% [markdown]
# # Phase 2: 그래프 구성 — 수집 → 분석 → 리스크 플로우
#
# Phase 1의 데이터 수집에 **분석 노드와 리스크 평가 노드**를 추가하여
# 완성된 분석 플로우를 구성합니다.
#
# ### 이 Phase에서 배우는 것
# - 조건부 엣지 (conditional edges)
# - 분석 노드 체인 구성
# - 그래프 확장 패턴

# %% [markdown]
# ## 1. 분석 노드 추가

# %% [markdown]
# ## 2. 그래프 구성 — 수집 → 분석 → 리스크

# %% [markdown]
# ## Phase 2 완료
#
# 데이터 수집 → 병렬 분석 → 리스크 평가 플로우를 구성했습니다.
#
# ```
# [START] → [수집] → [정량 분석] ─┐
#                  → [정성 분석] ─┤→ [리스크 평가] → [END]
# ```
#
# **다음 Phase**: 각 분석을 독립적인 에이전트로 분리하고 Supervisor로 관리합니다.
